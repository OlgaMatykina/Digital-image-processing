# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error

# %%
bh_data = load_boston()

# %%
print(bh_data.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
X=np.array([[185, 173],[185, 178],  [185, 164],  [201, 173],  [201, 178],  [201, 164],  [169, 173],  [169, 178],[169,164],[256,256],[256,246],[256,252],[256,249],[256,215],[256,223],[246,256],[246,246],[246,252],[246,249],[246,215],[246,223],[252,256],[252,246],[252,252],[252,249],[252,215],[252,223],[249,256],[249,246],[249,252],[249,249],[249,215],[249,223],[215,256],[215,246],[215,252],[215,249],[215,215],[215,223],[223,256],[223,246],[223,252],[223,249],[223,215],[223,223]])

# %%
print(X)
# Out:
# [[185 173]
#  [185 178]
#  [185 164]
#  [201 173]
#  [201 178]
#  [201 164]
#  [169 173]
#  [169 178]
#  [169 164]
#  [256 256]
#  [256 246]
#  [256 252]
#  [256 249]
#  [256 215]
#  [256 223]
#  [246 256]
#  [246 246]
#  [246 252]
#  [246 249]
#  [246 215]
#  [246 223]
#  [252 256]
#  [252 246]
#  [252 252]
#  [252 249]
#  [252 215]
#  [252 223]
#  [249 256]
#  [249 246]
#  [249 252]
#  [249 249]
#  [249 215]
#  [249 223]
#  [215 256]
#  [215 246]
#  [215 252]
#  [215 249]
#  [215 215]
#  [215 223]
#  [223 256]
#  [223 246]
#  [223 252]
#  [223 249]
#  [223 215]
#  [223 223]]

# %%
Y=np.array([[100],[100],[97],[113],[111],[109],[85],[85],[82],[194],[163],[88],[128],[89],[128],[159],[178],[88],[129],[90],[137],[87],[87],[90],[90],[76],[85],[128],[129],[89],[134],[90],[120],[89],[90],[79],[90],[90],[88],[129],[135],[87],[117],[88],[143]])

# %%
print(Y)
# Out:
# [[100]
#  [100]
#  [ 97]
#  [113]
#  [111]
#  [109]
#  [ 85]
#  [ 85]
#  [ 82]
#  [194]
#  [163]
#  [ 88]
#  [128]
#  [ 89]
#  [128]
#  [159]
#  [178]
#  [ 88]
#  [129]
#  [ 90]
#  [137]
#  [ 87]
#  [ 87]
#  [ 90]
#  [ 90]
#  [ 76]
#  [ 85]
#  [128]
#  [129]
#  [ 89]
#  [134]
#  [ 90]
#  [120]
#  [ 89]
#  [ 90]
#  [ 79]
#  [ 90]
#  [ 90]
#  [ 88]
#  [129]
#  [135]
#  [ 87]
#  [117]
#  [ 88]
#  [143]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state=9)

# %%
lin_reg_mod = LinearRegression()

# %%
lin_reg_mod.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = lin_reg_mod.predict(X_test)

# %%
test_set_rmse = (np.sqrt(mean_squared_error(y_test, pred)))

# %%
print(test_set_rmse)
# Out:
# 24.261569832708382

# %%
print(lin_reg_mod.coef_)
# Out:
# [[0.36207834 0.04102094]]

# %%
print(lin_reg_mod.intercept_)
# Out:
# [17.81892773]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
x = np.linspace(170, 255)
y = x
z = 17.81892773+0.36207834*x+0.041020945*y
fig = plt.figure(figsize=(20, 20))
ax = fig.add_subplot(111, projection='3d')
ax.plot(x, y, z, label='parametric curve')
sequence_containing_x_vals= X[0][:]
sequence_containing_y_vals = X[1][:]
sequence_containing_z_vals = [100, 100,  97, 113, 111, 109,  85,  85,  82, 194, 163,  88, 128,  89, 128, 159, 178,  88,  129,  90, 137,  87,  87,  90,  90,  76,  85, 128, 129,  89, 134,  90, 120,  89,  90,  79,  90,  90,  88, 129, 135,  87, 117,  88, 143]
ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
plt.show()

# %%
X=X.transpose()
Y=Y.transpose()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
print(Y)
x = X[0][:]
y = X[1][:]
z = [100, 100,  97, 113, 111, 109,  85,  85,  82, 194, 163,  88, 128,  89, 128, 159, 178,  88,  129,  90, 137,  87,  87,  90,  90,  76,  85, 128, 129,  89, 134,  90, 120,  89,  90,  79,  90,  90,  88, 129, 135,  87, 117,  88, 143]
print(x,y,z)
# Out:
# [[100 100  97 113 111 109  85  85  82 194 163  88 128  89 128 159 178  88
#   129  90 137  87  87  90  90  76  85 128 129  89 134  90 120  89  90  79
#    90  90  88 129 135  87 117  88 143]]
# [185 185 185 201 201 201 169 169 169 256 256 256 256 256 256 246 246 246
#  246 246 246 252 252 252 252 252 252 249 249 249 249 249 249 215 215 215
#  215 215 215 223 223 223 223 223 223] [173 178 164 173 178 164 173 178 164 256 246 252 249 215 223 256 246 252
#  249 215 223 256 246 252 249 215 223 256 246 252 249 215 223 256 246 252
#  249 215 223 256 246 252 249 215 223] [100, 100, 97, 113, 111, 109, 85, 85, 82, 194, 163, 88, 128, 89, 128, 159, 178, 88, 129, 90, 137, 87, 87, 90, 90, 76, 85, 128, 129, 89, 134, 90, 120, 89, 90, 79, 90, 90, 88, 129, 135, 87, 117, 88, 143]

# %%
import random

fig = plt.figure(figsize=(4, 4))
ax = fig.add_subplot(projection='3d')

sequence_containing_x_vals = x
sequence_containing_y_vals =  y
sequence_containing_z_vals = z

#random.shuffle(sequence_containing_x_vals)
#random.shuffle(sequence_containing_y_vals)
#random.shuffle(sequence_containing_z_vals)

ax.scatter(sequence_containing_x_vals, sequence_containing_y_vals, sequence_containing_z_vals)
plt.show()
