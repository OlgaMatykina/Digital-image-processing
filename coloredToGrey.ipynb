# %%
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 


image = Image.open("ezhik.jpg") #Открываем изображение. 
draw = ImageDraw.Draw(image) #Создаем инструмент для рисования. 
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 	
pix = image.load() #Выгружаем значения пикселей.
for i in range(width):
    for j in range(height):
        a = pix[i, j][0]
        b = pix[i, j][1]
        c = pix[i, j][2]
        S = (a + b + c) // 3
        draw.point((i, j), (S, S, S))
image.save("ezhik.jpg", "JPEG")

# %%
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 

image = Image.open("temp.jpg") #Открываем изображение. 
draw = ImageDraw.Draw(image) #Создаем инструмент для рисования. 
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 	
pix = image.load() #Выгружаем значения пикселей.
minim=255;
for i in range(width):
    for j in range(height):
        minim=min(minim, pix[i,j][0])
for i in range(width):
    for j in range(height):

        draw.point((i, j), (pix[i,j][0]-minim, pix[i,j][1]-minim, pix[i,j][2]-minim))
image.save("temp1.jpg", "JPEG")

# %%
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 

image = Image.open("nusha.jpg") #Открываем изображение. 
draw = ImageDraw.Draw(image) #Создаем инструмент для рисования. 
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 	
pix = image.load() #Выгружаем значения пикселей.
maxim=0;
for i in range(width):
    for j in range(height):
        maxim=max(maxim, pix[i,j][0])
for i in range(width):
    for j in range(height):

        draw.point((i, j), (round((pix[i,j][0]+50)*255/maxim), round((pix[i,j][1]+50)*255/maxim), round((pix[i,j][2]+50)*255/maxim)))
image.save("2.jpg", "JPEG")

# %%
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 

image = Image.open("nusha.jpg") #Открываем изображение. 
draw = ImageDraw.Draw(image) #Создаем инструмент для рисования. 
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 	
pix = image.load() #Выгружаем значения пикселей.
maxim=0;

for i in range(width):
    for j in range(height):
        if (pix[i,j][0]<50):
            draw.point((i, j),(50, 50, 50))
        elif (pix[i,j][0]>200):
            draw.point((i, j),(200, 200, 200))
        else:
            draw.point((i, j),(pix[i,j][0],pix[i,j][0],pix[i,j][0]))
image.save("medium2.jpg", "JPEG")

# %%
import random
from PIL import Image, ImageDraw #Подключим необходимые библиотеки. 

image = Image.open("forest.jpg") #Открываем изображение. 
draw = ImageDraw.Draw(image) #Создаем инструмент для рисования. 
width = image.size[0] #Определяем ширину. 
height = image.size[1] #Определяем высоту. 	
pix = image.load() #Выгружаем значения пикселей.
for i in range(width):
    for j in range(height):
        print(pix[i,j][0],' ',pix[i,j][1],' ',pix[i,j][2])
# Out:
# 31   47   8
# 42   63   0
# 141   165   69
# 147   170   64
# 171   191   102
# 133   147   88
# 122   129   95
# 47   52   32
# 47   50   39
# 44   47   38
# 45   53   30
# 47   58   15
# 86   101   44
# 106   122   73
# 77   89   69
# 37   44   52
# 26   46   0
# 77   95   37
# 35   52   10
# 38   54   28
# 39   58   36
# 27   51   19
# 62   90   41
# 101   134   63
# 88   123   39
# 70   104   17
# 126   157   77
# 58   84   19
# 108   130   81
# 28   45   9
# 27   41   15
# 46   60   37
# 55   91   30
# 61   95   35
# 32   63   6
# 109   138   84
# 62   88   40
# 75   96   53
# 90   108   70
# 81   96   63
# 57   67   40
# 41   49   26
# 57   64   46
# 56   60   45
# 31   35   21
# 32   35   24
# 58   59   51
# 30   31   23
# 29   42   0
# 29   41   5
# 84   97   54
# 81   97   35
# 52   71   7
# 20   35   0
# 35   45   34
# 35   47   25
# 45   62   7
# 27   46   0
# 26   40   4
# 34   41   34
# 59   64   58
# 31   39   16
# 30   39   12
# 29   34   14
# 39   44   38
# ...
